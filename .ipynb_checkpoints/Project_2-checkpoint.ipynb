# %%
import torch
import math
import matplotlib.pyplot as plt
import matplotlib.patches as pltp
torch.set_grad_enabled (False);

# %% [markdown]
# # Activation functions

# %%
class Tanh():  
    def forward(self, *input):
        self.s=input[0]
        return input[0].tanh()
    
    def backward(self, *gradwrtoutput):
        dl_dx=gradwrtoutput[0]
        dl_ds=(4 * (self.s.exp() + self.s.mul(-1).exp()).pow(-2))*dl_dx
        return dl_ds
    
    def param(self):
        return []  
    def reset(self):
        return []
    def update(self,eta):
        return []
    
class Relu():
    def forward(self, *input):
        self.s=input[0]
        return input[0].relu()
    
    def backward(self, *gradwrtoutput):
        dl_dx=gradwrtoutput[0]
        dl_ds=(self.s>0).float()*dl_dx
        return dl_ds
    
    def param(self):
        return []  
    def reset(self):
        return []
    def update(self,eta):
        return []

class Sigmoid():
    def forward(self, *input):
        self.s=input[0]
        return input[0].sigmoid()
    
    def backward(self, *gradwrtoutput):
        dl_dx=gradwrtoutput[0]
        dl_ds=(self.s.mul(-1).exp()/(1+self.s.mul(-1).exp()).pow(2))*dl_dx
        return dl_ds
    
    def param(self):
        return []  
    def reset(self):
        return []
    def update(self,eta):
        return []

# %% [markdown]
# # Layers and criterions

# %%
#  input in a tuple of tensor composed of the weights, the bias and the input vector   
# and return a tuple composed of the in put vector and the output vector
class Linear():
       
    def __init__(self,n_in,n_out):
        
        self.w = torch.empty(n_out, n_in).normal_()
        self.b =torch.empty(n_out).normal_()
        
        self.dl_dw = torch.empty(self.w.size())
        self.dl_db = torch.empty(self.b.size())
        self.x=torch.empty(n_in)
        
    def reset(self):
        self.dl_dw.zero_()
        self.dl_db.zero_()
    
    def forward(self, *input):
        self.x=input[0]
        return self.w.mv(self.x)+self.b
    
    def backward(self, *gradwrtoutput):
        dl_ds=gradwrtoutput[0]
        dl_dx=self.w.t().mv(dl_ds)
        self.dl_dw.add_(dl_ds.view(-1,1).mm(self.x.view(1,-1)))
        self.dl_db.add_(dl_ds)
        return dl_dx
        
    def param(self):
        return [[self.w,self.dl_dw],[self.b, self.dl_db]]
    
    def update(self,eta):
        self.w -= eta * self.dl_dw
        self.b -= eta * self.dl_db

class LossMSE():
    def loss(self,x,target):
        return (x - target).pow(2).sum()

    def dloss(self,x,target):
        dl_dx=2 * (x - target)
        return dl_dx
    
class CrossEntroyLoss():
    def loss(self,x,target):    
        return x.softmax(-1)[target].log10().mul(-1)

    def dloss(self,x,target):
        dl_dx=0 #TODO
        return dl_dx
    
class Sequential():
    def __init__(self,loss_method,*modules):
        self.network=modules
        self.loss_method=loss_method
        
    def forward(self,input):
        x=input
        for module in self.network:
            x=module.forward(x)
        return x
    
    def backward(self,output,target):
        x=loss_method.dloss(output,target)
        #go through the network backward
        for module in self.network[::-1]:
            x=module.backward(x)

# %% [markdown]
# # test

# %%
def generate_disc_set(nb):
    input = torch.Tensor(nb, 2).uniform_(0, 1)
    target = input.sub(0.5).pow(2).sum(1).sub(1/ (2*math.pi)).sign().sub(1).div(-2).long()
    return input, target

# %%
# import matplotlib.pyplot as plt
# point,color=generate_disc_set(10000)
# fig=plt.figure(figsize=(8, 8))
# plt.scatter(point[:,0],point[:,1],c=color,marker='.')
# plt.show()
# sum(color)

# %% [markdown]
# # MSE Loss

# %%
train_input,train_target=generate_disc_set(1000)
test_input,test_target=generate_disc_set(1000)

mean, std = train_input.mean(), train_input.std()
train_input.sub_(mean).div_(std)
test_input.sub_(mean).div_(std)

loss_method=LossMSE()
net=Sequential(loss_method,Linear(2,25),Tanh(),Linear(25,1),Sigmoid())
eta=1e-3
for i in range(100):
    acc_loss = 0
    nb_train_errors = 0
    nb_test_errors = 0
    
    for module in net.network:
        module.reset()
    for j in range(train_target.shape[0]):  
        output=net.forward(train_input[j,:])
        nb_train_errors+=int(bool(output>0.5)!=bool(train_target[j]))
        acc_loss += loss_method.loss(output,train_target[j]) 
        net.backward(output,train_target[j])
    for module in net.network:
#         print(module.param())
        module.update(eta)
    
    #test
    for j in range(test_target.shape[0]):  
        output=net.forward(test_input[j,:])
        nb_test_errors+=int(bool(output>0.5)!=bool(test_target[j]))
    print('{:d} acc_train_loss {:.02f} acc_train_error {:.02f}% test_error {:.02f}%'
      .format(i,
              acc_loss,
              (100 * nb_train_errors) / train_input.size(0),
              (100 * nb_test_errors) / test_input.size(0)))
# Out:
# 0 acc_train_loss 411.05 acc_train_error 49.80% test_error 46.80%
# 1 acc_train_loss 385.60 acc_train_error 47.80% test_error 45.10%
# 2 acc_train_loss 357.18 acc_train_error 46.00% test_error 44.30%
# 3 acc_train_loss 325.60 acc_train_error 44.90% test_error 41.20%
# 4 acc_train_loss 294.36 acc_train_error 40.40% test_error 34.60%
# 5 acc_train_loss 273.36 acc_train_error 34.10% test_error 32.70%
# 6 acc_train_loss 263.02 acc_train_error 33.40% test_error 32.90%
# 7 acc_train_loss 254.67 acc_train_error 33.30% test_error 32.60%
# 8 acc_train_loss 244.50 acc_train_error 33.30% test_error 32.60%
# 9 acc_train_loss 231.21 acc_train_error 32.40% test_error 31.30%
# 10 acc_train_loss 214.87 acc_train_error 33.10% test_error 31.50%
# 11 acc_train_loss 199.17 acc_train_error 32.20% test_error 30.20%
# 12 acc_train_loss 187.99 acc_train_error 29.10% test_error 28.50%
# 13 acc_train_loss 179.11 acc_train_error 26.70% test_error 24.80%
# 14 acc_train_loss 171.45 acc_train_error 22.90% test_error 23.20%
# 15 acc_train_loss 164.77 acc_train_error 22.10% test_error 21.60%
# 16 acc_train_loss 158.89 acc_train_error 21.40% test_error 21.00%
# 17 acc_train_loss 153.65 acc_train_error 20.20% test_error 20.30%
# 18 acc_train_loss 148.93 acc_train_error 19.60% test_error 20.00%
# 19 acc_train_loss 144.63 acc_train_error 18.60% test_error 19.50%
# 20 acc_train_loss 140.67 acc_train_error 18.40% test_error 19.10%
# 21 acc_train_loss 136.99 acc_train_error 17.90% test_error 18.80%
# 22 acc_train_loss 133.54 acc_train_error 17.30% test_error 18.10%
# 23 acc_train_loss 130.29 acc_train_error 16.80% test_error 16.90%
# 24 acc_train_loss 127.21 acc_train_error 16.50% test_error 16.00%
# 25 acc_train_loss 124.28 acc_train_error 16.30% test_error 15.80%
# 26 acc_train_loss 121.48 acc_train_error 15.40% test_error 15.10%
# 27 acc_train_loss 118.80 acc_train_error 15.00% test_error 14.80%
# 28 acc_train_loss 116.23 acc_train_error 14.40% test_error 14.00%
# 29 acc_train_loss 113.76 acc_train_error 13.60% test_error 13.50%
# 30 acc_train_loss 111.40 acc_train_error 12.60% test_error 13.20%
# 31 acc_train_loss 109.13 acc_train_error 12.00% test_error 12.80%
# 32 acc_train_loss 106.95 acc_train_error 11.60% test_error 12.40%
# 33 acc_train_loss 104.87 acc_train_error 11.10% test_error 12.00%
# 34 acc_train_loss 102.88 acc_train_error 10.30% test_error 11.30%
# 35 acc_train_loss 100.97 acc_train_error 10.00% test_error 10.80%
# 36 acc_train_loss 99.14 acc_train_error 9.70% test_error 10.40%
# 37 acc_train_loss 97.40 acc_train_error 9.30% test_error 9.70%
# 38 acc_train_loss 95.74 acc_train_error 8.70% test_error 9.20%
# 39 acc_train_loss 94.16 acc_train_error 8.50% test_error 9.10%
# 40 acc_train_loss 92.65 acc_train_error 8.10% test_error 8.90%
# 41 acc_train_loss 91.22 acc_train_error 7.70% test_error 8.60%
# 42 acc_train_loss 89.85 acc_train_error 7.30% test_error 8.30%
# 43 acc_train_loss 88.55 acc_train_error 7.00% test_error 7.90%
# 44 acc_train_loss 87.31 acc_train_error 6.70% test_error 7.50%
# 45 acc_train_loss 86.13 acc_train_error 6.30% test_error 7.40%
# 46 acc_train_loss 85.01 acc_train_error 5.80% test_error 6.70%
# 47 acc_train_loss 83.94 acc_train_error 5.40% test_error 6.40%
# 48 acc_train_loss 82.92 acc_train_error 4.90% test_error 6.20%
# 49 acc_train_loss 81.95 acc_train_error 4.60% test_error 5.90%
# 50 acc_train_loss 81.02 acc_train_error 4.20% test_error 5.80%
# 51 acc_train_loss 80.13 acc_train_error 3.80% test_error 5.40%
# 52 acc_train_loss 79.28 acc_train_error 3.40% test_error 5.00%
# 53 acc_train_loss 78.47 acc_train_error 3.00% test_error 5.00%
# 54 acc_train_loss 77.69 acc_train_error 3.00% test_error 4.50%
# 55 acc_train_loss 76.94 acc_train_error 2.90% test_error 4.60%
# 56 acc_train_loss 76.22 acc_train_error 2.80% test_error 4.60%
# 57 acc_train_loss 75.53 acc_train_error 2.90% test_error 4.30%
# 58 acc_train_loss 74.86 acc_train_error 2.90% test_error 4.20%
# 59 acc_train_loss 74.21 acc_train_error 2.90% test_error 3.80%
# 60 acc_train_loss 73.59 acc_train_error 2.60% test_error 3.60%
# 61 acc_train_loss 72.99 acc_train_error 2.60% test_error 3.60%
# 62 acc_train_loss 72.41 acc_train_error 2.60% test_error 3.50%
# 63 acc_train_loss 71.84 acc_train_error 2.50% test_error 3.40%
# 64 acc_train_loss 71.30 acc_train_error 2.50% test_error 3.30%
# 65 acc_train_loss 70.77 acc_train_error 2.40% test_error 3.20%
# 66 acc_train_loss 70.25 acc_train_error 2.40% test_error 3.10%
# 67 acc_train_loss 69.75 acc_train_error 2.40% test_error 3.10%
# 68 acc_train_loss 69.26 acc_train_error 2.40% test_error 3.10%
# 69 acc_train_loss 68.78 acc_train_error 2.30% test_error 3.10%
# 70 acc_train_loss 68.32 acc_train_error 2.30% test_error 3.10%
# 71 acc_train_loss 67.87 acc_train_error 2.30% test_error 3.10%
# 72 acc_train_loss 67.43 acc_train_error 2.30% test_error 3.10%
# 73 acc_train_loss 67.00 acc_train_error 2.20% test_error 3.10%
# 74 acc_train_loss 66.57 acc_train_error 2.10% test_error 3.00%
# 75 acc_train_loss 66.16 acc_train_error 2.10% test_error 2.90%
# 76 acc_train_loss 65.76 acc_train_error 2.00% test_error 2.90%
# 77 acc_train_loss 65.36 acc_train_error 1.90% test_error 2.90%
# 78 acc_train_loss 64.98 acc_train_error 1.90% test_error 2.90%
# 79 acc_train_loss 64.60 acc_train_error 1.80% test_error 2.90%
# 80 acc_train_loss 64.23 acc_train_error 1.80% test_error 2.80%
# 81 acc_train_loss 63.86 acc_train_error 1.90% test_error 2.80%
# 82 acc_train_loss 63.51 acc_train_error 1.90% test_error 2.80%
# 83 acc_train_loss 63.15 acc_train_error 1.90% test_error 2.80%
# 84 acc_train_loss 62.81 acc_train_error 1.90% test_error 2.70%
# 85 acc_train_loss 62.47 acc_train_error 1.90% test_error 2.70%
# 86 acc_train_loss 62.14 acc_train_error 1.90% test_error 2.60%
# 87 acc_train_loss 61.81 acc_train_error 1.80% test_error 2.60%
# 88 acc_train_loss 61.49 acc_train_error 1.80% test_error 2.60%
# 89 acc_train_loss 61.18 acc_train_error 1.80% test_error 2.60%
# 90 acc_train_loss 60.87 acc_train_error 1.80% test_error 2.50%
# 91 acc_train_loss 60.56 acc_train_error 1.80% test_error 2.50%
# 92 acc_train_loss 60.26 acc_train_error 1.80% test_error 2.50%
# 93 acc_train_loss 59.97 acc_train_error 1.80% test_error 2.50%
# 94 acc_train_loss 59.68 acc_train_error 1.80% test_error 2.50%
# 95 acc_train_loss 59.39 acc_train_error 1.80% test_error 2.50%
# 96 acc_train_loss 59.11 acc_train_error 1.80% test_error 2.50%
# 97 acc_train_loss 58.83 acc_train_error 1.80% test_error 2.50%
# 98 acc_train_loss 58.55 acc_train_error 1.80% test_error 2.50%
# 99 acc_train_loss 58.28 acc_train_error 1.70% test_error 2.50%

# %%
# LossMSE

test_input,test_target=generate_disc_set(10000)
test_input.sub_(mean).div_(std)
output=torch.empty(10000)
decision=torch.empty(10000)
for j in range(test_target.shape[0]):  
    output[j]=net.forward(test_input[j,:])
    decision[j]= int(bool(output[j]>0.5))


fig=plt.figure(figsize=(8, 8))
color=decision
circle1=plt.Circle((0.5,0.5), 1/math.sqrt(2*math.pi),linewidth=2 ,color='r',fill=False)
plt.gcf().gca().add_artist(circle1)
test_input.mul_(std).add_(mean)
plt.scatter(test_input[:,0],test_input[:,1],c=color,s=5)
plt.show()
        
test_input,test_target=generate_disc_set(10000)
test_input.sub_(mean).div_(std)
output=torch.empty(10000)
decision=torch.empty(10000)
for j in range(test_target.shape[0]):  
    output[j]=net.forward(test_input[j,:])

fig=plt.figure(figsize=(16, 8))
color=test_target
plt.scatter(output,torch.ones(10000),c=color,marker='.',s=0.2)
plt.plot([0.5,0.5],[0,2],'r')
plt.show()

# %% [markdown]
# # Cross entropy loss

# %%
train_input,train_target=generate_disc_set(1000)
test_input,test_target=generate_disc_set(1000)

mean, std = train_input.mean(), train_input.std()
train_input.sub_(mean).div_(std)
test_input.sub_(mean).div_(std)

loss_method=CrossEntroyLoss()
net=Sequential(loss_method,Linear(2,25),Tanh(),Linear(25,2),Sigmoid())
eta=1e-3

for i in range(25):
    acc_loss = 0
    nb_train_errors = 0
    nb_test_errors = 0
    
    for module in net.network:
        module.reset()
    for j in range(train_target.shape[0]):  
        output=net.forward(train_input[j,:])

        nb_train_errors+=int(bool(output.argmax())!=bool(test_target[j]))
        acc_loss += loss_method.loss(output,train_target[j]) 
        net.backward(output,train_target[j])
    for module in net.network:
#         print(module.param())
        module.update(eta)
    
    #test
    for j in range(test_target.shape[0]):  
        output=net.forward(test_input[j,:])
        nb_test_errors+= int(bool(output.argmax())!=bool(test_target[j]))
    print('{:d} acc_train_loss {:.02f} acc_train_error {:.02f}% test_error {:.02f}%'
      .format(i,
              acc_loss,
              (100 * nb_train_errors) / train_input.size(0),
              (100 * nb_test_errors) / test_input.size(0)))
# Out:
# 0 acc_train_loss 316.69 acc_train_error 52.70% test_error 40.20%
# 1 acc_train_loss 314.24 acc_train_error 52.70% test_error 40.00%
# 2 acc_train_loss 312.07 acc_train_error 52.70% test_error 39.90%
# 3 acc_train_loss 311.34 acc_train_error 52.30% test_error 39.90%
# 4 acc_train_loss 312.95 acc_train_error 52.40% test_error 40.00%
# 5 acc_train_loss 316.62 acc_train_error 52.10% test_error 40.40%
# 6 acc_train_loss 320.32 acc_train_error 52.40% test_error 40.70%
# 7 acc_train_loss 322.74 acc_train_error 52.60% test_error 41.30%
# 8 acc_train_loss 324.13 acc_train_error 52.60% test_error 41.10%
# 9 acc_train_loss 324.84 acc_train_error 52.80% test_error 40.90%
# 10 acc_train_loss 325.00 acc_train_error 53.30% test_error 41.20%
# 11 acc_train_loss 324.69 acc_train_error 54.00% test_error 41.70%
# 12 acc_train_loss 323.98 acc_train_error 53.90% test_error 42.40%
# 13 acc_train_loss 323.07 acc_train_error 54.50% test_error 42.30%
# 14 acc_train_loss 322.21 acc_train_error 54.60% test_error 42.80%
# 15 acc_train_loss 321.40 acc_train_error 55.00% test_error 42.90%
# 16 acc_train_loss 320.23 acc_train_error 54.60% test_error 43.10%
# 17 acc_train_loss 318.27 acc_train_error 54.70% test_error 43.40%
# 18 acc_train_loss 315.41 acc_train_error 54.40% test_error 43.90%
# 19 acc_train_loss 312.02 acc_train_error 54.50% test_error 44.20%
# 20 acc_train_loss 308.82 acc_train_error 54.30% test_error 44.30%
# 21 acc_train_loss 306.35 acc_train_error 54.90% test_error 44.60%
# 22 acc_train_loss 304.71 acc_train_error 54.60% test_error 44.70%
# 23 acc_train_loss 303.68 acc_train_error 54.50% test_error 44.90%
# 24 acc_train_loss 303.02 acc_train_error 54.30% test_error 45.30%

# %%
# crossEntropyLoss

test_input,test_target=generate_disc_set(10000)
test_input.sub_(mean).div_(std)
output=torch.empty(10000,2)
decision=torch.empty(10000)
for j in range(test_target.shape[0]):  
    output[j,:]=net.forward(test_input[j,:])
    decision[j]= int(bool(output[j,:].argmax()))


fig=plt.figure(figsize=(8, 8))
color=decision
circle1=plt.Circle((0.5,0.5), 1/math.sqrt(2*math.pi),linewidth=2 ,color='r',fill=False)
plt.gcf().gca().add_artist(circle1)
test_input.mul_(std).add_(mean)
plt.scatter(test_input[:,0],test_input[:,1],c=color,s=5)
plt.show()
        
test_input,test_target=generate_disc_set(10000)
test_input.sub_(mean).div_(std)
output=torch.empty(10000,2)
decision=torch.empty(10000)
for j in range(test_target.shape[0]):  
    output[j,:]=net.forward(test_input[j,:])

fig=plt.figure(figsize=(16, 8))
color=test_target
plt.scatter(output[:,0],output[:,1],c=color,marker='.',s=0.2)
plt.show()
